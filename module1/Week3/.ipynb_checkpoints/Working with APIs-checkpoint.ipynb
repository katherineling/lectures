# %%
import json
import requests

response = requests.get('https://jsonplaceholder.typicode.com/todos')

# %%
type(response)
# Out:
# requests.models.Response

# %%
results = response.json()
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
# ...

# %%
type(results)
# Out:
# list

# %%
import pandas as pd
data = pd.DataFrame(results)
data.head(10)
# Out:
#    completed  id                                              title  userId
# 0      False   1                                 delectus aut autem       1
# 1      False   2                 quis ut nam facilis et officia qui       1
# 2      False   3                                fugiat veniam minus       1
# 3       True   4                                   et porro tempora       1
# 4      False   5  laboriosam mollitia et enim quasi adipisci qui...       1
# 5      False   6  qui ullam ratione quibusdam voluptatem quia omnis       1
# 6      False   7                  illo expedita consequatur quia in       1
# 7       True   8                       quo adipisci enim quam ut ab       1
# 8      False   9                        molestiae perspiciatis ipsa       1
# 9       True  10       illo est ratione doloremque quia maiores aut       1

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json())
data.head(10)
# Out:
#                                                actor            created_at  \
# 0  {'id': 8517910, 'login': 'LombiqBot', 'display...  2019-06-24T14:05:16Z
# 1  {'id': 46543736, 'login': 'gluhass', 'display_...  2019-06-24T14:05:16Z
# 2  {'id': 42819689, 'login': 'whitesource-bolt-fo...  2019-06-24T14:05:16Z
# 3  {'id': 340766, 'login': 'pablocubico', 'displa...  2019-06-24T14:05:16Z
# 4  {'id': 4694577, 'login': 'camwatson', 'display...  2019-06-24T14:05:16Z
# 5  {'id': 4403806, 'login': 'RussKie', 'display_l...  2019-06-24T14:05:16Z
# 6  {'id': 30715889, 'login': 'ZRRJDD', 'display_l...  2019-06-24T14:05:16Z
# 7  {'id': 46305024, 'login': 'Romanski1', 'displa...  2019-06-24T14:05:16Z
# 8  {'id': 49273227, 'login': 'MichaelKubiak', 'di...  2019-06-24T14:05:16Z
# 9  {'id': 33192870, 'login': 'sankarchinnam07', '...  2019-06-24T14:05:16Z
#
#            id                                                org  \
# 0  9881121764  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# ...

# %%
pd.DataFrame(dict(data['actor'])).transpose()
# Out:
#                                            avatar_url  \
# 0    https://avatars.githubusercontent.com/u/8517910?
# 1   https://avatars.githubusercontent.com/u/46543736?
# 2   https://avatars.githubusercontent.com/u/42819689?
# 3     https://avatars.githubusercontent.com/u/340766?
# 4    https://avatars.githubusercontent.com/u/4694577?
# 5    https://avatars.githubusercontent.com/u/4403806?
# 6   https://avatars.githubusercontent.com/u/30715889?
# 7   https://avatars.githubusercontent.com/u/46305024?
# 8   https://avatars.githubusercontent.com/u/49273227?
# 9   https://avatars.githubusercontent.com/u/33192870?
# 10  https://avatars.githubusercontent.com/u/17277667?
# 11  https://avatars.githubusercontent.com/u/32104679?
# 12  https://avatars.githubusercontent.com/u/22951616?
# 13  https://avatars.githubusercontent.com/u/33012994?
# 14  https://avatars.githubusercontent.com/u/33332964?
# 15  https://avatars.githubusercontent.com/u/30896344?
# ...

# %%
data.columns
# Out:
# Index(['actor', 'created_at', 'id', 'org', 'payload', 'public', 'repo',
#        'type'],
#       dtype='object')

# %%
x = pd.DataFrame(data['actor'][0], index=[0])
x.head()
y = pd.DataFrame(data['actor'][1], index=[1])
y.head()
pd.concat([x,y],axis=0)
# Out:
#         id      login display_login gravatar_id  \
# 0  8517910  LombiqBot     LombiqBot
# 1  1146750    8emezzo       8emezzo
#
#                                       url  \
# 0  https://api.github.com/users/LombiqBot
# 1    https://api.github.com/users/8emezzo
#
#                                          avatar_url
# 0  https://avatars.githubusercontent.com/u/8517910?
# 1  https://avatars.githubusercontent.com/u/1146750?

# %%
cols = data['actor'][0].keys()
cols
# Out:
# dict_keys(['id', 'login', 'display_login', 'gravatar_id', 'url', 'avatar_url'])

# %%
newDF = pd.DataFrame(columns=cols)
newDF.head()
# Out:
# Empty DataFrame
# Columns: [id, login, display_login, gravatar_id, url, avatar_url]
# Index: []

# %%
for i in range(len(data['actor'])):
    x = pd.DataFrame(data['actor'][i], index=[i])
    newDF = pd.concat([newDF,x],axis=0)

# %%
newDF.head()
# Out:
#          id                             login                display_login  \
# 0   8517910                         LombiqBot                    LombiqBot
# 1  46543736                           gluhass                      gluhass
# 2  42819689  whitesource-bolt-for-github[bot]  whitesource-bolt-for-github
# 3    340766                       pablocubico                  pablocubico
# 4   4694577                         camwatson                    camwatson
#
#   gravatar_id                                                url  \
# 0                         https://api.github.com/users/LombiqBot
# 1                           https://api.github.com/users/gluhass
# 2              https://api.github.com/users/whitesource-bolt-...
# 3                       https://api.github.com/users/pablocubico
# 4                         https://api.github.com/users/camwatson
#
#                                           avatar_url
# 0   https://avatars.githubusercontent.com/u/8517910?
# ...

# %%
newDF = pd.DataFrame(columns=cols)
newDF.head()

newDF.head(10)

# %%
def flatten(data, colname):
    cols = data[colname][0].keys()
    newDF = pd.DataFrame(columns=cols)
    newDF.head()
    for i in range(len(data[colname])):
        x = pd.DataFrame(data[colname][i], index=[i])
        newDF = pd.concat([newDF,x],axis=0)
    newDF.head(10)
    return(newDF)

actors = flatten(data,'actor')
# orgs = flatten(data,'org')
# payloads = flatten(data,'payload')
repos = flatten(data,'repo')

# %%
pd.DataFrame(dict(data['org']))
# Out:
#                                                            0   1   2   \
# avatar_url   https://avatars.githubusercontent.com/u/8158177? NaN NaN
# gravatar_id                                                   NaN NaN
# id                                                    8158177 NaN NaN
# login                                                  Lombiq NaN NaN
# url                        https://api.github.com/orgs/Lombiq NaN NaN
#
#                                                           3   4   \
# avatar_url   https://avatars.githubusercontent.com/u/727698? NaN
# gravatar_id                                                  NaN
# id                                                    727698 NaN
# login                                             greenpeace NaN
# url                   https://api.github.com/orgs/greenpeace NaN
#
#                                                            5   6   7   8   9   \
# ...

# %%
pd.DataFrame(dict(data['org'])).transpose()
# Out:
#                                            avatar_url gravatar_id        id  \
# 0    https://avatars.githubusercontent.com/u/8158177?               8158177
# 1                                                 NaN         NaN       NaN
# 2                                                 NaN         NaN       NaN
# 3     https://avatars.githubusercontent.com/u/727698?                727698
# 4                                                 NaN         NaN       NaN
# 5    https://avatars.githubusercontent.com/u/1700077?               1700077
# 6                                                 NaN         NaN       NaN
# 7                                                 NaN         NaN       NaN
# 8                                                 NaN         NaN       NaN
# 9                                                 NaN         NaN       NaN
# 10                                                NaN         NaN       NaN
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['actor', 'org', 'payload', 'repo']
flat = flatten(data, nested_columns)
flat.head(10)
# Out:
#              created_at          id  public              type  \
# 0  2019-06-24T14:05:16Z  9881121764    True         PushEvent
# 1  2019-06-24T14:05:16Z  9881121735    True         PushEvent
# 2  2019-06-24T14:05:16Z  9881121729    True         PushEvent
# 3  2019-06-24T14:05:16Z  9881121722    True         PushEvent
# 4  2019-06-24T14:05:16Z  9881121694    True         PushEvent
# 5  2019-06-24T14:05:16Z  9881121706    True  PullRequestEvent
# 6  2019-06-24T14:05:16Z  9881121705    True        WatchEvent
# 7  2019-06-24T14:05:16Z  9881121701    True        WatchEvent
# 8  2019-06-24T14:05:16Z  9881121695    True       CreateEvent
# 9  2019-06-24T14:05:16Z  9881121687    True  PullRequestEvent
#
#                                     actor_avatar_url  \
# 0   https://avatars.githubusercontent.com/u/8517910?
# 1  https://avatars.githubusercontent.com/u/46543736?
# 2  https://avatars.githubusercontent.com/u/42819689?
# 3    https://avatars.githubusercontent.com/u/340766?
# ...

# %%
from pandas.io.json import json_normalize
response = requests.get('https://api.github.com/events')
results = response.json()
flattened_data = json_normalize(results)
flattened_data = pd.DataFrame(flattened_data)
flattened_data.head()
# Out:
#                                     actor.avatar_url actor.display_login  \
# 0  https://avatars.githubusercontent.com/u/32673226?          Tumbraegel
# 1   https://avatars.githubusercontent.com/u/1761087?         davidjgraph
# 2  https://avatars.githubusercontent.com/u/17317030?           arnaucube
# 3     https://avatars.githubusercontent.com/u/16392?               joeyh
# 4  https://avatars.githubusercontent.com/u/15093472?             ludeeus
#
#   actor.gravatar_id  actor.id  actor.login  \
# 0                    32673226   Tumbraegel
# 1                     1761087  davidjgraph
# 2                    17317030    arnaucube
# 3                       16392        joeyh
# 4                    15093472      ludeeus
#
#                                   actor.url            created_at          id  \
# 0   https://api.github.com/users/Tumbraegel  2019-06-24T14:50:45Z  9881515161
# 1  https://api.github.com/users/davidjgraph  2019-06-24T14:50:45Z  9881515150
# ...
