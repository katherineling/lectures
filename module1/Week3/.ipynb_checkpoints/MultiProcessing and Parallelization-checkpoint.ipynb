# %% [markdown]
# The first type of time is called CPU or execution time, which measures how much time a CPU spent on
# executing a program. The second type of time is called wall-clock time, which measures the total time
# to execute a program in a computer. The wall-clock time is also called elapsed or running time.
# Compared to the CPU time, the wall-clock time is often longer because the CPU executing the measured
# program may also be executing other program's instructions at the same time.
#
# Another important concept is the so-called system time, which is measured by the system clock.
# System time represents a computer system's notion of the passing of time. One should remember that the system clock could be modified by the operating system, thus modifying the system time.

# %%
import multiprocessing

# %%
def square(x):  
    return x*x

data = [x for x in range(100)]

# %%
# %%time
data_squared = [square(x) for x in range(100)]
print(data_squared)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225, 4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776, 5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569, 7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604, 9801]
# CPU times: user 209 µs, sys: 140 µs, total: 349 µs
# Wall time: 274 µs

# %%
import time 
start_time = time.time()
data_squared = [square(x) for x in range(100)]
print(time.time()-start_time)
print(data_squared)
# Out:
# 7.390975952148438e-05
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225, 4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776, 5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569, 7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604, 9801]

# %%
# %%time
pool = multiprocessing.Pool()
result = pool.map(square, data)
pool.terminate()
pool.join()
print(result)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225, 4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776, 5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569, 7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604, 9801]
# CPU times: user 12.6 ms, sys: 18.6 ms, total: 31.2 ms
# Wall time: 141 ms

# %%
import os
dirs = os.listdir('./directories')
dirs.remove('.DS_Store')
print(dirs)
# Out:
# ['dir40', 'dir78', 'dir47', 'dir71', 'dir85', 'dir49', 'dir82', 'dir76', 'dir22', 'dir25', 'dir13', 'dir14', 'dir48', 'dir77', 'dir83', 'dir84', 'dir70', 'dir79', 'dir46', 'dir41', 'dir15', 'dir12', 'dir24', 'dir23', 'dir2', 'dir5', 'dir39', 'dir30', 'dir37', 'dir63', 'dir97', 'dir90', 'dir64', 'dir52', 'dir99', 'dir55', 'dir36', 'dir31', 'dir38', 'dir4', 'dir3', 'dir54', 'dir53', 'dir98', 'dir65', 'dir91', 'dir96', 'dir62', 'dir26', 'dir19', 'dir21', 'dir17', 'dir28', 'dir10', 'dir44', 'dir88', 'dir43', 'dir81', 'dir75', 'dir72', 'dir86', 'dir11', 'dir16', 'dir29', 'dir20', 'dir27', 'dir18', 'dir87', 'dir73', 'dir74', 'dir80', 'dir89', 'dir42', 'dir45', 'dir93', 'dir67', 'dir58', 'dir60', 'dir94', 'dir56', 'dir69', 'dir51', 'dir6', 'dir1', 'dir34', 'dir8', 'dir33', 'dir50', 'dir57', 'dir68', 'dir95', 'dir61', 'dir66', 'dir92', 'dir59', 'dir32', 'dir9', 'dir35', 'dir0', 'dir7']

# %% [markdown]
# the dot operator means the directory we are in currently and directories is the folder from which we want to
# list the names of the folders inside it

# %%
dirs1 = os.listdir('/Users/himanshuaggarwal/ironhack/himanshu')
print(dirs1)
print('\n')
dirs2 = os.listdir('./directories/dir40')
print(dirs2)
# Out:
# ['labs-lectures-modules', '.DS_Store', 'lab-solutions', '.ipynb_checkpoints', 'data']
#
#
# ...

# %%
def find_markdowns(dir):
    files = os.listdir('./directories/'+dir)
    markdowns = [dir +'/' + file for file in files if file.endswith('.md')]
